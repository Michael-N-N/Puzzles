# %% [markdown]
# # How Fast Can You Skip To Your Favorite Song? (2019-12-06)
#
# link: https://fivethirtyeight.com/features/how-fast-can-you-skip-to-your-favorite-song/

# %% [markdown]
# ## I. Puzzle (Riddler Express)

# %% [markdown]
# After being ambushed by the forces of the First Order on the planet Jakku, the droid BB-8 narrowly escaped and requires immediate help. Fortunately, there is one person (named Rey) on the planet who can help BB-8, but they’ve never met and BB-8 has no idea where Rey is located.
#
# Even if BB-8 did know where Rey was, what’s the probability that BB-8 could reach her within 24 hours? Assume Jakku has a radius of 4,000 miles (similar to Earth) and that BB-8 rolls along at a speed of 3 miles per hour.
#
# (Note: FiveThirtyEight is owned by Disney, which also owns BB-8, Jakku and whatever ramshackle hut Rey is hiding out in.)

# %% [markdown]
# # II. Solution

# %% [markdown]
# The probability that BB-8 will find Rey is the ratio of the surface area BB-8 can reach within a day ($A_{sc}$) to the surface area of the plant ($A_s$): $$P = \frac{A_{sc}}{A_s}$$
# The surface area BB-8 can reach forms a spherical cap

# %%
from IPython import display
display.Image("files/surfacecap.png", width = 200)

# %% [markdown]
# and it can be determined by:
# $$A_{sc} =2 \pi r^2(1-\text{cos } \theta)$$
#
# The surface area of the planet is
#
# $$A_s=4 \pi r^2$$
#
# This gives us for the probability:
#
# $$P = \frac{2 \pi r^2(1-\text{cos } \theta)}{4 \pi r^2}=\frac{1-\text{cos } \theta}{2}$$
#
# The angle $\theta$ can be determined by the ration between the length BB-8 can travel within 25 hours with a speed of 3 miles per hour and the circumference of the planet:
#
# $$\theta = 360° \frac{3 \cdot 24}{2 \pi 4,000}= \frac{81°}{25}$$
# This give a probability of:
# $$P = \frac{1}{2} \bigg(1-\text{cos } \frac{81°}{25}\bigg)\approx 8 \cdot 10^{-5}$$
